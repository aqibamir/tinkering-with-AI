# %% [markdown]
# # Training Data

# %%
prompts = [
     # First creating dataset for single element printing on the screen
    "Create a json for a video with text 'Hello World' with duration 3 seconds",
    "Create a video with only one element for 5 seconds with text 'Hi there !'",
    "Video with only one text element where text lasts for 6 seconds. The text is Where are you going today. The total length of the video is 10 seconds",
    
    "Create a video with only 1 text element with white background for 2 seconds and.The content on the screen should be 'this is black'",
    "display text for 4 seconds that says Hello World in blue background",
    "Create JSON for a video of screen size 1366x768 for text 'Who is Aqib ?' in grey background and blue font color for 2 seconds. Total length of the video is 4 seconds.",
    "Create a video with two text elements the first text element appears for 2 seconds and the second text element appears for 4 seconds. The content of the first text element is 'Hi I'm an AI' and the content of the second element is 'Who are you'",
    "Create JSON for a video . Display text where it says 'Helllo world' for 3 seconds. Second display another text message that says 'Write code' for 3 seconds. The font color of the first element is green and the color of the second is blue.",
    "Display a text that says 'what are you ?' for three seconds. Then display a text message that says 'I'm Human' in white background and black text for 2 seconds. Then display a text that says 'I'm an AI' for 4 seconds ",
    "Display text 'hello' and then change the text to 'what are you' after 3 seconds and then to 'hahahah' after 5 seconds for 2 seonds",
    
    "Create a JSON for a video that shows random text 3 second. The text is then changed to 'hi there !' in white background and after that the text is changed to 'whats up' after 5 seconds for 3 seoncds",
    "Generate a video with of 10 seconds in length. Display text that says what are you upto in white background and blue font color. Then change the text to 'Hahah' and after 4 seconds change the text to what are you upto",
    "Generate a video that says 'Hi, I'm an AI' for 2 seconds and then who are you for 4 seonds",
    "Create JSON for a video of screen size 1920x1080 that displays a text element for 3 seconds that says ' who are you' in white background and black font color. After 3 seconds change the text to 'hello how are you' with grey background and white font color. After three seconds change the text to who are you. Afer three more seconds change the text to 'i'm shutting down'",
    "a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second. Then write 'third' for 1 second, and then write 'hey, fourth' for 2 seconds, and then write 'fifth here' for 3 secconds in green on a red background.",
    "a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second.",
    "a video that is 1920x1080. In this video, first display 'This is my first text' in white on a black background for 1 second, then replace it with 'This is my second text' for 1 second",
    
    "a video that is 1920x1080 and 3 seconds long, with the text 'This text is only visible for one second' in white on a black background. The text should only be visible for one second",
    "Generate a video with dimensions 1920x1080. Start with the text 'Learning is Fun' in colorful font on a white background for 4 seconds. Then, switch to 'Stay Curious' in bold font on a dark background for the next 5 seconds.",
    "Generate a video with a screen size of 1920x1080 and a duration of 6 seconds. Display 'Happy Holidays' in red font color on a green background for the first 3 seconds. Then, switch to 'New Year Wishes' in gold font color on a blue background for the remaining 3 seconds.",
    "Design a video with dimensions 1920x1080. Show a single text element saying 'Exciting News' in blue on a white background for 5 seconds.",
    "Build a JSON for a video of size 1366x768. Feature two text elements  the first, 'Hello World' in black on a yellow background for 3 seconds, and the second, 'Goodbye' in white on a red background for the next 4 seconds.",
    "Create a video with a duration of 7 seconds. Display the text 'Sunshine' in yellow on a blue background for the first 4 seconds. Afterward, change it to 'Moonlight' in white on a black background for the remaining time.",
    "Generate a video with a screen size of 1920x1080. Start with the text 'On Air' in red on a black background for 2 seconds. Transition to 'Live Broadcast' in white on a blue background for the next 3 seconds. Conclude with 'Thank You' in yellow on a green background for the last 2 seconds."

]

# %%
ai_output = [
  {
    "duration": "3 s",
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Hello World",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "5 s",
        "text": "Hi there !",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "duration": "10 s",
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "6 s",
        "text": "Where are you going today",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "2 s",
        "background_color": "#ffffff",
        "fill_color": "#000000",
        "text": "this is black",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "4 s",
  "elements": [
    {
      "type": "text",
      "time": "0 s",
      "track": 1,
      "duration": "4 s",
      "text": "Hello World",
      "background_color": "#0000FF",
      "fill_color": "#FFFFFF", 
      "font_family": "Open Sans"
    }
  ]
},
  
  {
    "duration": "4 s",
    "width": 1366,
    "height": 768,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "2 s",
        "background_color": "#808080",
        "fill_color": "#0000FF",
        "text": "Who is Aqib ?",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "6 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "Hi, I'm an AI",
      "background_color": "#FFFFFF",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "4 s",
      "text": "Who are you",
      "background_color": "#FFFFFF",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    }
  ]
},
  
  {
    "duration": "4 s",
    "width": 1920,
    "height": 1280,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "fill_color": "#008000",
        "duration": "3 s",
        "text": "Hello World",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "fill_color": "#0000FF",
        "text": "Write code",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "What are you?",
        "fill_color":"#ffffff",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "2 s",
        "background_color": "#ffffff",
        "fill_color": "#000000",
        "text": "I'm Human",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "text": "I'm an AI",
        "fill_color":"#ffffff",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "hello",
        "fill_color": "#ffffff",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "5 s",
        "text": "What are you",
        "fill_color": "#ffffff",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "2 s",
        "text": "hahahah",
        "fill_color": "#ffffff",
        "font_family": "Open Sans"
      }
    ]
  },
    
  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "3 s",
      "text": "random text",
      "fill_color": "#ffffff",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "5 s",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "text": "hi there!",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "3 s",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "text": "whats up",
      "font_family": "Open Sans"
    }
  ]
},
  
  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "10 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "What are you up to",
      "background_color": "#FFFFFF",
      "fill_color": "#0000FF",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "4 s",
      "text": "Hahah",
      "background_color": "#FFFFFF",
      "fill_color": "#0000FF",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "4 s",
      "text": "What are you up to",
      "background_color": "#FFFFFF",
      "fill_color": "#0000FF",
      "font_family": "Open Sans"
    }
  ]
},

  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "6 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "Hi, I'm an AI",
      "background_color": "#FFFFFF",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "4 s",
      "text": "Who are you",
      "background_color": "#FFFFFF",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    }
  ]
},
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "12 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Who are you",
        "background_color": "#FFFFFF",
        "fill_color": "#000000",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Hello, how are you",
        "background_color": "#808080",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Who are you",
        "background_color": "#FFFFFF",
        "fill_color": "#000000",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "I'm shutting down",
        "background_color": "#FFFFFF",
        "fill_color": "#000000",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "13 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "text": "This is my first text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "This is my second text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "1 s",
        "text": "third",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "2 s",
        "text": "hey, fourth",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "fifth here",
        "background_color": "#FF0000",
        "fill_color": "#008000",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "7 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "4 s",
        "text": "This is my first text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "4 s",
        "track": 1,
        "duration": "3 s",
        "text": "This is my second text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "2 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "1 s",
        "text": "This is my first text",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "1 s",
        "track": 1,
        "duration": "1 s",
        "text": "This is my second text",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "3 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "1 s",
        "text": "This text is only visible for one second",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "9 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "text": "Learning is Fun",
        "background_color": "#FFFFFF",
        "fill_color": "#FF0000",
        "font_weight": "normal",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "5 s",
        "text": "Stay Curious",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_weight": "bold",
        "font_family": "Open Sans"
      }
    ]
  },

    {
      "width": 1920,
      "height": 1080,
      "output_format": "mp4",
      "duration": "6 s",
      "elements": [
        {
          "type": "text",
          "track": 1,
          "duration": "3 s",
          "text": "Happy Holidays",
          "background_color": "#008000",
          "fill_color": "#FF0000",
          "font_family": "Open Sans"
        },
        {
          "type": "text",
          "track": 1,
          "duration": "3 s",
          "text": "New Year Wishes",
          "background_color": "#0000FF",
          "fill_color": "#FFD700",
          "font_family": "Open Sans"
        }
      ]
    },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "5 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "5 s",
        "text": "Exciting News",
        "background_color": "#FFFFFF",
        "fill_color": "#0000FF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1366,
    "height": 768,
    "output_format": "mp4",
    "duration": "7 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Hello World",
        "background_color": "#FFFF00",
        "fill_color": "#000000",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "text": "Goodbye",
        "background_color": "#FF0000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "7 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "4 s",
      "text": "Sunshine",
      "background_color": "#0000FF",
      "fill_color": "#FFFF00",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "3 s",
      "text": "Moonlight",
      "background_color": "#000000",
      "fill_color": "#FFFFFF",
      "font_family": "Open Sans"
    }
  ]
},

  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "7 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "On Air",
      "background_color": "#000000",
      "fill_color": "#FF0000",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "3 s",
      "text": "Live Broadcast",
      "background_color": "#0000FF",
      "fill_color": "#FFFFFF",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "Thank You",
      "background_color": "#008000",
      "fill_color": "#FFFF00",
      "font_family": "Open Sans"
    }
  ]
}

]

# %%
import json

system_prompt = "You are an assistant that generates JSON for a video given a user prompt"

def write_jsonl(file_path,prompts, ai_output):
    with open(file_path, 'w') as file:
        for prompt, output  in zip(prompts,ai_output):
            json.dump({"messages": [{"role": "system", "content": system_prompt}, {"role": "user", "content": prompt}, {"role": "assistant", "content": json.dumps(output)}]}, file)
            file.write('\n')

write_jsonl('dataset.jsonl',prompts,ai_output)

# %%
import json
import tiktoken # for token counting
import numpy as np
from collections import defaultdict

# %%
data_path = "dataset.jsonl"

# Load the dataset
with open(data_path, 'r') as f:
    dataset = [json.loads(line) for line in f]

# Initial dataset stats
print("Num examples:", len(dataset))
print("First example:")
for message in dataset[0]["messages"]:
    print(message)
# Out:
# Num examples: 24
# First example:
# {'role': 'system', 'content': 'You are an assistant that generates JSON for a video given a user prompt'}
# {'role': 'user', 'content': "Create a json for a video with text 'Hello World' with duration 3 seconds"}
# {'role': 'assistant', 'content': '{"duration": "3 s", "width": 1920, "height": 1080, "output_format": "mp4", "elements": [{"type": "text", "track": 1, "duration": "3 s", "text": "Hello World", "font_family": "Open Sans"}]}'}

# %%
# Format error checks
format_errors = defaultdict(int)

for ex in dataset:
    if not isinstance(ex, dict):
        format_errors["data_type"] += 1
        continue
        
    messages = ex.get("messages", None)
    if not messages:
        format_errors["missing_messages_list"] += 1
        continue
        
    for message in messages:
        if "role" not in message or "content" not in message:
            format_errors["message_missing_key"] += 1
        
        if any(k not in ("role", "content", "name", "function_call") for k in message):
            format_errors["message_unrecognized_key"] += 1
        
        if message.get("role", None) not in ("system", "user", "assistant", "function"):
            format_errors["unrecognized_role"] += 1
            
        content = message.get("content", None)
        function_call = message.get("function_call", None)
        
        if (not content and not function_call) or not isinstance(content, str):
            format_errors["missing_content"] += 1
    
    if not any(message.get("role", None) == "assistant" for message in messages):
        format_errors["example_missing_assistant_message"] += 1

if format_errors:
    print("Found errors:")
    for k, v in format_errors.items():
        print(f"{k}: {v}")
else:
    print("No errors found")
# Out:
# No errors found

# %%
encoding = tiktoken.get_encoding("cl100k_base")

# not exact!
# simplified from https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb
def num_tokens_from_messages(messages, tokens_per_message=3, tokens_per_name=1):
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3
    return num_tokens

def num_assistant_tokens_from_messages(messages):
    num_tokens = 0
    for message in messages:
        if message["role"] == "assistant":
            num_tokens += len(encoding.encode(message["content"]))
    return num_tokens

def print_distribution(values, name):
    print(f"\n#### Distribution of {name}:")
    print(f"min / max: {min(values)}, {max(values)}")
    print(f"mean / median: {np.mean(values)}, {np.median(values)}")
    print(f"p5 / p95: {np.quantile(values, 0.1)}, {np.quantile(values, 0.9)}")

# %%
# Warnings and tokens counts
n_missing_system = 0
n_missing_user = 0
n_messages = []
convo_lens = []
assistant_message_lens = []

for ex in dataset:
    messages = ex["messages"]
    if not any(message["role"] == "system" for message in messages):
        n_missing_system += 1
    if not any(message["role"] == "user" for message in messages):
        n_missing_user += 1
    n_messages.append(len(messages))
    convo_lens.append(num_tokens_from_messages(messages))
    assistant_message_lens.append(num_assistant_tokens_from_messages(messages))
    
print("Num examples missing system message:", n_missing_system)
print("Num examples missing user message:", n_missing_user)
print_distribution(n_messages, "num_messages_per_example")
print_distribution(convo_lens, "num_total_tokens_per_example")
print_distribution(assistant_message_lens, "num_assistant_tokens_per_example")
n_too_long = sum(l > 4096 for l in convo_lens)
print(f"\n{n_too_long} examples may be over the 4096 token limit, they will be truncated during fine-tuning")
# Out:
# Num examples missing system message: 0
# Num examples missing user message: 0
#
# #### Distribution of num_messages_per_example:
# min / max: 3, 3
# mean / median: 3.0, 3.0
# p5 / p95: 3.0, 3.0
#
# #### Distribution of num_total_tokens_per_example:
# min / max: 108, 418
# mean / median: 212.54166666666666, 218.5
# p5 / p95: 132.0, 280.9
#
# #### Distribution of num_assistant_tokens_per_example:
# min / max: 61, 295
# mean / median: 135.5, 136.0
# p5 / p95: 71.8, 188.2
#
# 0 examples may be over the 4096 token limit, they will be truncated during fine-tuning

# %%
# Pricing and default n_epochs estimate
MAX_TOKENS_PER_EXAMPLE = 4096

TARGET_EPOCHS = 3
MIN_TARGET_EXAMPLES = 100
MAX_TARGET_EXAMPLES = 25000
MIN_DEFAULT_EPOCHS = 1
MAX_DEFAULT_EPOCHS = 25

n_epochs = TARGET_EPOCHS
n_train_examples = len(dataset)
if n_train_examples * TARGET_EPOCHS < MIN_TARGET_EXAMPLES:
    n_epochs = min(MAX_DEFAULT_EPOCHS, MIN_TARGET_EXAMPLES // n_train_examples)
elif n_train_examples * TARGET_EPOCHS > MAX_TARGET_EXAMPLES:
    n_epochs = max(MIN_DEFAULT_EPOCHS, MAX_TARGET_EXAMPLES // n_train_examples)

n_billing_tokens_in_dataset = sum(min(MAX_TOKENS_PER_EXAMPLE, length) for length in convo_lens)
print(f"Dataset has ~{n_billing_tokens_in_dataset} tokens that will be charged for during training")
print(f"By default, you'll train for {n_epochs} epochs on this dataset")
print(f"By default, you'll be charged for ~{n_epochs * n_billing_tokens_in_dataset} tokens")
# Out:
# Dataset has ~5101 tokens that will be charged for during training
# By default, you'll train for 4 epochs on this dataset
# By default, you'll be charged for ~20404 tokens

# %%
from openai import OpenAI
from dotenv import load_dotenv

# Load the enviroment variables
load_dotenv()

client = OpenAI()

training_file = client.files.create(
  file=open("dataset.jsonl", "rb"),
  purpose="fine-tune"
)
  

job_id = client.fine_tuning.jobs.create(
  training_file= training_file.id, 
  model="gpt-3.5-turbo"
)

# %%
fine_tunning_job = client.fine_tuning.jobs.retrieve(job_id.id)

# %%
fine_tunning_job
# Out:
# FineTuningJob(id='ftjob-vrjMsZ8RgeL7e9vW3I2vjJi3', created_at=1703593404, error=None, fine_tuned_model='ft:gpt-3.5-turbo-0613:cogent-labs::8a0rU7gk', finished_at=1703593811, hyperparameters=Hyperparameters(n_epochs=4, batch_size=1, learning_rate_multiplier=2), model='gpt-3.5-turbo-0613', object='fine_tuning.job', organization_id='org-m6RAnp8W8R8g1JCO21xA019z', result_files=['file-iNTJIkojo7Cz4QAxF6Zc7IPo'], status='succeeded', trained_tokens=20212, training_file='file-5xiLlUkKo3lhm9uuXCzgbkRP', validation_file=None)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

def invoke_model(prompt,model_id = "ft:gpt-3.5-turbo-0613:cogent-labs::8a0rU7gk"):
    chat_template = ChatPromptTemplate.from_messages(
        [
            ("system", "{system_prompt}"),
            ("user", "{user_input}")
        ]
    )

    model = ChatOpenAI(model=model_id)

    ai_generation = chat_template | model 
    ai_message = ai_generation.invoke({"system_prompt":system_prompt, "user_input":prompt})

    print(ai_message.content)

# %%
invoke_model("a video that is 1920x1080 and 3 seconds long, with the text 'This text is only visible for one econd' in white on a black background. The text should only be visible for one second")
# Out:
# {"width": 1920, "height": 1080, "output_format": "mp4", "duration": "3 s", "elements": [{"type": "text", "track": 1, "duration": "1 s", "text": "This text is only visible for one second", "background_color": "#000000", "fill_color": "#FFFFFF", "font_family": "Open Sans"}]}

# %%
invoke_model("a video that is 1920x1080. In this video, first display 'This is my first text' in white on a black background for 1 second, then replace it with 'This is my second text' for 1 second")
# Out:
# {"width": 1920, "height": 1080, "output_format": "mp4", "duration": "2 s", "elements": [{"type": "text", "track": 1, "duration": "1 s", "text": "This is my first text", "background_color": "#000000", "fill_color": "#FFFFFF", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "1 s", "text": "This is my second text", "background_color": "#000000", "fill_color": "#FFFFFF", "font_family": "Open Sans"}]}

# %%
invoke_model("a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second.")
# Out:
# {"width": 1920, "height": 1080, "output_format": "mp4", "duration": "7 s", "elements": [{"type": "text", "track": 1, "duration": "4 s", "text": "This is my first text", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "3 s", "text": "This is my second text", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}]}

# %%
invoke_model("a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second. Then write 'third' for 1 second.")
# Out:
# {"width": 1920, "height": 1080, "output_format": "mp4", "duration": "8 s", "elements": [{"type": "text", "track": 1, "duration": "4 s", "text": "This is my first text", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "3 s", "text": "This is my second text", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "1 s", "text": "third", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}]}

# %%
invoke_model("a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second. Then write 'third' for 1 second, and then write 'hey, fourth' for 2 seconds, and then write 'fifth here' for 3 seconds in green on a red background")
# Out:
# {"width": 1920, "height": 1080, "output_format": "mp4", "duration": "13 s", "elements": [{"type": "text", "track": 1, "duration": "4 s", "text": "This is my first text", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "3 s", "text": "This is my second text", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "1 s", "text": "third", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "2 s", "text": "hey, fourth", "background_color": "#0000FF", "fill_color": "#FFFF00", "font_family": "Open Sans"}, {"type": "text", "track": 1, "duration": "3 s", "text": "fifth here", "background_color": "#FF0000", "fill_color": "#008000", "font_family": "Open Sans"}]}
