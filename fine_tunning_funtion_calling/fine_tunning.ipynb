# %% [markdown]
# # Training Data

# %%
prompts = [
     # First creating dataset for single element printing on the screen
    "Create a video with only one element for 5 seconds with text 'Hi there !'",
    "Video with only one text element where text lasts for 6 seconds. The text is Where are you going today. The total length of the video is 10 seconds",
    "Create a video with only 1 text element with white background for 2 seconds and.The content on the screen should be 'this is black'"
    "display text for 4 seconds that says Hello World in blue background",
    "Create JSON for a video of screen size 1366x768 for text 'Who is Aqib ?' in grey background and blue font color for 2 seconds. Total length of the video is 4 seconds. The text appears at time 2 seconds",
    "Create a video with two text elements the first text element appears at 2 seconds and the second text element appears at 4 seconds. The content of the first text element is 'Hi I'm an AI' and the content of the second element is 'Who are you'",
    "Create JSON for a video . Display text at 2 seconds where it says 'Helllo world' for 3 seconds. At 6th second display another text message that says 'Write code'. The font color of the first element is green and the color of the second is blue.",
    "Display a text that says 'what are you ?' at 3rd second. Then display a text message that says 'I'm Human' at 5th second in white background and black text for 2 seconds. Then display a text that says 'I'm an AI' for 4 seconds ",
    "Display text 'hello' at time 1 second and then change the text to 'what are you' after 3 seconds and then to 'hahahah' after 5 seconds",
    "Create a JSON for a video that shows random text at 3rd second. After 2 s the text is changed to 'hi there !' in white background and after that the text is changed to 'whats up' after 5 seconds",
    "Generate a video with of 10 seconds in length. Display text for 2 seconds that says what are you upto in white background and blue font color. Then change the text after 3 seonds to 'Hahah' and after 4 seconds change the text to what are you upto",
    "Create JSON for a video of screen size 1920x1080 that displays a text element for 3 seconds that says ' who are you' in white background and black font color. After 3 seconds change the text to 'hello how are you' with grey background and white font color. After three seconds change the text to who are you. Afer three more seconds change the text to 'i'm shutting down'",
    "a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second. Then write 'third' for 1 second, and then write 'hey, fourth' for 2 seconds, and then write 'fifth here' for 3 secconds in green on a red background.",
    "a video that is 1920x1080. In this video, first display 'This is my first text' in yellow on a blue background for 4 second, then replace it with 'This is my second text' for 3 second.",
    "Create JSON for a video that is 1920x1080 and 3 seconds long with text 'Hello World",
    "a video that is 1920x1080. In this video, first display 'This is my first text' in white on a black background for 1 second, then replace it with 'This is my second text' for 1 second",
    "a video that is 1920x1080 and 3 seconds long, with the text 'This text is only visible for one second' in white on a black background. The text should only be visible for one second",
    "Generate a video with dimensions 1920x1080. Start with the text 'Learning is Fun' in colorful font on a white background for 4 seconds. Then, switch to 'Stay Curious' in bold font on a dark background for the next 5 seconds.",
    "Design a video with dimensions 1920x1080. Show a single text element saying 'Exciting News' in blue on a white background for 5 seconds.",
    "Build a JSON for a video of size 1366x768. Feature two text elements  the first, 'Hello World' in black on a yellow background for 3 seconds, and the second, 'Goodbye' in white on a red background for the next 4 seconds.",
    "Create a video with a duration of 7 seconds. Display the text 'Sunshine' in yellow on a blue background for the first 4 seconds. Afterward, change it to 'Moonlight' in white on a black background for the remaining time.",
    "Generate a video with a screen size of 1920x1080. Start with the text 'On Air' in red on a black background for 2 seconds. Transition to 'Live Broadcast' in white on a blue background for the next 3 seconds. Conclude with 'Thank You' in yellow on a green background for the last 2 seconds."

]

# %%
ai_output = [
  {
    "duration": "3 s",
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Hello World",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "5 s",
        "text": "Hi there",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "duration": "10 s",
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "6 s",
        "text": "Hi there",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "2 s",
        "background_color": "#ffffff",
        "fill_color": "#000000",
        "text": "this is black",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "background_color": "#0000FF",
        "text": "this is black",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "duration": "4 s",
    "width": 1366,
    "height": 768,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "time": "2 s",
        "track": 1,
        "duration": "2 s",
        "background_color": "#808080",
        "fill_color": "#0000FF",
        "text": "Who is Aqib ?",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "duration": "4 s",
    "width": 1920,
    "height": 1280,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "time": "2 s",
        "track": 1,
        "fill_color": "#008000",
        "duration": "3 s",
        "text": "Hello World",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "6 s",
        "track": 1,
        "duration": "2 s",
        "fill_color": "#0000FF",
        "text": "Write code",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "time": "3 s",
        "track": 1,
        "duration": "2 s",
        "text": "What are you?",
        "fill_color":"#ffffff",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "5 s",
        "track": 1,
        "duration": "2 s",
        "background_color": "#ffffff",
        "fill_color": "#000000",
        "text": "I'm Human",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "text": "I'm an AI",
        "fill_color":"#ffffff",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "elements": [
      {
        "type": "text",
        "time": "1 s",
        "track": 1,
        "duration": "2 s",
        "text": "hello",
        "fill_color": "#ffffff",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "3 s",
        "track": 1,
        "duration": "2 s",
        "text": "What are you",
        "fill_color": "#ffffff",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "5 s",
        "track": 1,
        "duration": "2 s",
        "text": "hahahah",
        "fill_color": "#ffffff",
        "font_family": "Open Sans"
      }
    ]
  },
  
  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "elements": [
    {
      "type": "text",
      "time": "3 s",
      "track": 1,
      "duration": "2 s",
      "text": "random text",
      "fill_color": "#ffffff",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "time": "5 s",
      "track": 1,
      "duration": "2 s",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "text": "hi there!",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "time": "7 s",
      "track": 1,
      "duration": "2 s",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "text": "whats up",
      "font_family": "Open Sans"
    }
  ]
},
  
  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "12 s",
  "elements": [
    {
      "type": "text",
      "time": "0 s",
      "track": 1,
      "duration": "3 s",
      "text": "Who are you",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "time": "3 s",
      "track": 1,
      "duration": "3 s",
      "text": "Hello, how are you",
      "background_color": "#808080",
      "fill_color": "#ffffff",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "time": "6 s",
      "track": 1,
      "duration": "3 s",
      "text": "Who are you",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "time": "9 s",
      "track": 1,
      "duration": "3 s",
      "text": "I'm shutting down",
      "background_color": "#ffffff",
      "fill_color": "#000000",
      "font_family": "Open Sans"
    }
  ]
},
  
  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "13 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "4 s",
        "text": "This is my first text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "4 s",
        "track": 1,
        "duration": "3 s",
        "text": "This is my second text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "7 s",
        "track": 1,
        "duration": "1 s",
        "text": "third",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "8 s",
        "track": 1,
        "duration": "2 s",
        "text": "hey, fourth",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "10 s",
        "track": 1,
        "duration": "3 s",
        "text": "fifth here",
        "background_color": "#FF0000",
        "fill_color": "#008000",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "7 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "4 s",
        "text": "This is my first text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "4 s",
        "track": 1,
        "duration": "3 s",
        "text": "This is my second text",
        "background_color": "#0000FF",
        "fill_color": "#FFFF00",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "3 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "3 s",
        "text": "Hello World",
        "font_family": "Open Sans",
        "background_color": "#000000",
        "fill_color": "#FFFFFF"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "2 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "1 s",
        "text": "This is my first text",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "1 s",
        "track": 1,
        "duration": "1 s",
        "text": "This is my second text",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "3 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "1 s",
        "text": "This text is only visible for one second",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "9 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "4 s",
        "text": "Learning is Fun",
        "background_color": "#FFFFFF",
        "fill_color": "#FF0000",
        "font_weight": "normal",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "time": "4 s",
        "track": 1,
        "duration": "5 s",
        "text": "Stay Curious",
        "background_color": "#000000",
        "fill_color": "#FFFFFF",
        "font_weight": "bold",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "6 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Happy Holidays",
        "background_color": "#008000",
        "fill_color": "#FF0000",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "New Year Wishes",
        "background_color": "#0000FF",
        "fill_color": "#FFD700",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1920,
    "height": 1080,
    "output_format": "mp4",
    "duration": "5 s",
    "elements": [
      {
        "type": "text",
        "time": "0 s",
        "track": 1,
        "duration": "5 s",
        "text": "Exciting News",
        "background_color": "#FFFFFF",
        "fill_color": "#0000FF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
    "width": 1366,
    "height": 768,
    "output_format": "mp4",
    "duration": "7 s",
    "elements": [
      {
        "type": "text",
        "track": 1,
        "duration": "3 s",
        "text": "Hello World",
        "background_color": "#FFFF00",
        "fill_color": "#000000",
        "font_family": "Open Sans"
      },
      {
        "type": "text",
        "track": 1,
        "duration": "4 s",
        "text": "Goodbye",
        "background_color": "#FF0000",
        "fill_color": "#FFFFFF",
        "font_family": "Open Sans"
      }
    ]
  },

  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "7 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "4 s",
      "text": "Sunshine",
      "background_color": "#0000FF",
      "fill_color": "#FFFF00",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "3 s",
      "text": "Moonlight",
      "background_color": "#000000",
      "fill_color": "#FFFFFF",
      "font_family": "Open Sans"
    }
  ]
},

  {
  "width": 1920,
  "height": 1080,
  "output_format": "mp4",
  "duration": "7 s",
  "elements": [
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "On Air",
      "background_color": "#000000",
      "fill_color": "#FF0000",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "3 s",
      "text": "Live Broadcast",
      "background_color": "#0000FF",
      "fill_color": "#FFFFFF",
      "font_family": "Open Sans"
    },
    {
      "type": "text",
      "track": 1,
      "duration": "2 s",
      "text": "Thank You",
      "background_color": "#008000",
      "fill_color": "#FFFF00",
      "font_family": "Open Sans"
    }
  ]
}

]

# %%
import json

system_prompt = "You are an assistant that generates JSON for a video given a user prompt"

def write_jsonl(file_path,prompts, ai_output):
    with open(file_path, 'w') as file:
        for prompt, output  in zip(prompts,ai_output):
            json.dump({"messages": [{"role": "system", "content": system_prompt}, {"role": "user", "content": prompt}, {"role": "assistant", "content": output}]}, file)
            file.write('\n')

write_jsonl('dataset.jsonl',prompts,ai_output)

# %%
import tiktoken # for token counting
import numpy as np
from collections import defaultdict
import json

# %%
data_path = "dataset.jsonl"

# Load the dataset
with open(data_path, 'r') as f:
    dataset = [json.loads(line) for line in f]

# Initial dataset stats
print("Num examples:", len(dataset))
print("First example:")
for message in dataset[0]["messages"]:
    print(message)
# Out:
# Num examples: 21
# First example:
# {'role': 'system', 'content': 'You are an assistant that generates JSON for a video given a user prompt'}
# {'role': 'user', 'content': "Create a video with only one element for 5 seconds with text 'Hi there !'"}
# {'role': 'assistant', 'content': {'duration': '3 s', 'width': 1920, 'height': 1080, 'output_format': 'mp4', 'elements': [{'type': 'text', 'track': 1, 'duration': '3 s', 'text': 'Hello World', 'font_family': 'Open Sans'}]}}

# %%
from openai import OpenAI
from dotenv import load_dotenv

# Load the enviroment variables
load_dotenv()

client = OpenAI()

client.files.create(
  file=open("dataset.jsonl", "rb"),
  purpose="fine-tune"
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[11], line 9
#       5 load_dotenv()
#       7 client = OpenAI()
# ----> 9 client.files.create(
#      10   file=open("dataset.jsonl", "rb"),
#      11   purpose="fine-tune"
#      12 )
#
# File ~/.local/lib/python3.8/site-packages/openai/resources/files.py:96, in Files.create(self, file, purpose, extra_headers, extra_query, extra_body, timeout)
#      90 if files:
#      91     # It should be noted that the actual Content-Type header that will be
#      92     # sent to the server will contain a `boundary` parameter, e.g.
#      93     # multipart/form-data; boundary=---abc--
#      94     extra_headers = {"Content-Type": "multipart/form-data", **(extra_headers or {})}
# ---> 96 return self._post(
#      97     "/files",
#      98     body=maybe_transform(body, file_create_params.FileCreateParams),
# ...
